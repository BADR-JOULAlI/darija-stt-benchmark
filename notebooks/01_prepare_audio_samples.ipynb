# %% [markdown]
# # 01 — Utiliser les extraits audio déjà collectés
#
# Le SQLite est sur un autre PC : ce notebook utilise directement les MP3 présents dans `audio/`. Il ne contacte ni le SQLite, ni YouTube, ni l'API Mistral.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from benchmark import discover_existing_audio_samples

# %%
selected = discover_existing_audio_samples()
print(f'{len(selected)} audios existants détectés.')
selected[:3]

# %% [markdown]
# Résultat attendu sur cette machine : **34 audios de 120 secondes**. Passez ensuite au notebook `02_run_mistral_benchmark.ipynb`.
