# %% [markdown]
# # 00 — Inspection du dataset existant
# Ce notebook ouvre le dataset en lecture seule, détecte la table et la colonne contenant les liens YouTube, sans modifier la source.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
from dataset_loader import inspect_dataset, iter_youtube_records

# %%
DATASET_PATH = Path(r'C:\Users\BadrJOULALI\Downloads\darija_youtube_extraction\darija_youtube_clean.sqlite')
info = inspect_dataset(DATASET_PATH)
info
# Out:
# {'path': 'C:\\Users\\BadrJOULALI\\Downloads\\darija_youtube_extraction\\darija_youtube_clean.sqlite',
#  'format': 'sqlite',
#  'table': 'videos',
#  'url_column': 'video_url',
#  'columns': ['video_id',
#   'video_url',
#   'channel_ref',
#   'channel_id',
#   'channel_url',
#   'channel_title',
#   'title',
#   'description',
#   'tags',
#   'duration',
#   'view_count',
#   'like_count',
#   'comment_count',
#   'upload_date',
#   'timestamp',
#   'language',
#   'availability',
#   'darija_score',
#   'is_darija',
#   'source',
#   'checked_at',
#   'hydrated_at',
#   'license_raw',
#   'license_normalized',
#   'is_cc_by',
#   'license_filter_reason'],
#  'row_count': 818874,
#  'filter': 'is_darija = 1'}

# %%
# Aperçu non destructif des cinq premières URLs.
records = iter_youtube_records(DATASET_PATH)
[next(records)['youtube_url'] for _ in range(5)]
# Out:
# ['https://www.youtube.com/watch?v=iZa06jAEi5c',
#  'https://www.youtube.com/watch?v=b04iTOyzEPo',
#  'https://www.youtube.com/watch?v=CJF3xc-hoBM',
#  'https://www.youtube.com/watch?v=UvkYT5syIaU',
#  'https://www.youtube.com/watch?v=pUYmlJ9BJKs']
